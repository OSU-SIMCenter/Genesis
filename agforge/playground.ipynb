# %%
import trimesh

mesh = trimesh.load('../meshes/proc_cyl_stock.obj')
min_bb, max_bb = mesh.bounds
print("Min:", min_bb)
print("Max:", max_bb)
# Out:
# Min: [-5.31171823 -1.50355637 -1.5035249 ]
# Max: [3.8233006  1.50361538 1.50361145]

# %%
import trimesh
import matplotlib.pyplot as plt

# Load mesh
mesh = trimesh.load('../meshes/proc_cyl_stock.obj')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x, y, z = mesh.vertices.T
faces = mesh.faces

ax.plot_trisurf(x, y, z, triangles=faces, color='lightgray', edgecolor='k', alpha=0.7)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()  # Interactive window with mouse control for rotation/zoom/pan
